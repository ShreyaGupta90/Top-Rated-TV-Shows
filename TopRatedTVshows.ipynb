# %%
import numpy as np
import requests as r
import pandas as pd

# %%
response=r.get("https://api.themoviedb.org/3/discover/tv?api_key=ab9c6cb13f050b38772655608f40bd53&include_adult=false&language=en-US&page=1&sort_by=vote_average.desc&vote_count.gte=200")

# %%
pd.DataFrame(response.json()['results'])[['id','name','first_air_date','overview','popularity','vote_average','vote_count']]
# Out:
#         id                              name first_air_date  \
# 0     1396                      Breaking Bad     2008-01-20
# 1   209867     Frieren: Beyond Journey's End     2023-09-29
# 2   240411                        Dan Da Dan     2024-10-04
# 3   220542            The Apothecary Diaries     2023-10-22
# 4    94954                      Hazbin Hotel     2024-01-18
# 5    94605                            Arcane     2021-11-06
# 6   129888            Twenty Five Twenty One     2022-02-12
# 7      246        Avatar: The Last Airbender     2005-02-21
# 8    37854                         One Piece     1999-10-20
# 9    31911  Fullmetal Alchemist: Brotherhood     2009-04-05
# 10   60625                    Rick and Morty     2013-12-02
# 11   60059                  Better Call Saul     2015-02-08
# 12   87108                         Chernobyl     2019-05-06
# 13  135157                  Alchemy of Souls     2022-06-18
# 14    1429                   Attack on Titan     2013-04-07
# 15   70785                    Anne with an E     2017-03-19
# 16  221851                  Marry My Husband     2024-01-01
# 17   42705                   Fighting Spirit     2000-10-03
# 18   92685                     The Owl House     2020-01-10
# 19   85937    Demon Slayer: Kimetsu no Yaiba     2019-04-06
#
#                                              overview  popularity  \
# 0   Walter White, a New Mexico chemistry teacher, ...     712.364
# 1   After the party of heroes defeated the Demon K...     122.031
# 2   In a bet to prove whether ghosts or aliens exi...     383.562
# 3   Maomao lived a peaceful life with her apotheca...     160.967
# 4   In attempt to find a non-violent alternative f...     108.720
# 5   Amid the stark discord of twin cities Piltover...     371.175
# 6   In a time when dreams seem out of reach, a tee...      93.856
# 7   In a war-torn world of elemental magic, a youn...      70.421
# 8   Years ago, the fearsome Pirate King, Gol D. Ro...     364.261
# 9   Disregard for alchemy’s laws ripped half of Ed...      92.425
# 10  Rick is a mentally-unbalanced but scientifical...     461.522
# 11  Six years before Saul Goodman meets Walter Whi...     333.718
# 12  The true story of one of the worst man-made ca...     160.277
# 13  A powerful sorceress in a blind woman's body e...     206.201
# 14  Many years ago, the last remnants of humanity ...     105.220
# 15  A coming-of-age story about an outsider who, a...     103.949
# 16  Kang Ji-won, a terminally ill cancer patient, ...     123.960
# 17  Makunouchi Ippo is an ordinary high school stu...    1363.754
# 18  An animated fantasy-comedy series that follows...     148.770
# 19  It is the Taisho Period in Japan. Tanjiro, a k...     176.925
#
#     vote_average  vote_count
# 0          8.900       14776
# 1          8.840         351
# 2          8.829         334
# 3          8.800         205
# 4          8.800        1192
# 5          8.800        4712
# 6          8.755         212
# 7          8.734        4182
# 8          8.700        4748
# 9          8.698        2091
# 10         8.700        9863
# 11         8.691        5339
# 12         8.682        6455
# 13         8.700         616
# 14         8.700        6493
# 15         8.666        4671
# 16         8.664         480
# 17         8.700        1086
# 18         8.656        1612
# 19         8.654        6525

# %%
df=pd.DataFrame()

# %%
for i in range(1,106):
  response=r.get("https://api.themoviedb.org/3/discover/tv?api_key=ab9c6cb13f050b38772655608f40bd53&include_adult=false&language=en-US&page={}&sort_by=vote_average.desc&vote_count.gte=200".format(i))
  temp_df=pd.DataFrame(response.json()['results'])[['id','name','first_air_date','overview','popularity','vote_average','vote_count']]
  df=pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#           id                           name first_air_date  \
# 0       1396                   Breaking Bad     2008-01-20
# 1     209867  Frieren: Beyond Journey's End     2023-09-29
# 2     240411                     Dan Da Dan     2024-10-04
# 3     220542         The Apothecary Diaries     2023-10-22
# 4      94954                   Hazbin Hotel     2024-01-18
# ...      ...                            ...            ...
# 2093  135251                       The Idol     2023-06-04
# 2094  130392              The D'Amelio Show     2021-09-03
# 2095   10160                    Big Brother     2000-07-05
# 2096    1871                     EastEnders     1985-02-19
# 2097  126725                          Velma     2023-01-12
#
#                                                overview  popularity  \
# 0     Walter White, a New Mexico chemistry teacher, ...     712.364
# 1     After the party of heroes defeated the Demon K...     122.031
# 2     In a bet to prove whether ghosts or aliens exi...     383.562
# 3     Maomao lived a peaceful life with her apotheca...     160.967
# 4     In attempt to find a non-violent alternative f...     108.720
# ...                                                 ...         ...
# 2093  After a nervous breakdown derailed Jocelyn's l...      57.043
# 2094  From relative obscurity and a seemingly normal...      14.340
# 2095  American version of the reality game show whic...      99.918
# 2096  The everyday lives of working-class residents ...     301.205
# 2097  Jinkies! This raucous reimagining of the Scoob...      52.490
#
#       vote_average  vote_count
# 0            8.900       14776
# 1            8.840         351
# 2            8.829         334
# 3            8.800         205
# 4            8.800        1192
# ...            ...         ...
# 2093         5.423         248
# 2094         5.000         681
# 2095         4.978         232
# 2096         4.100         207
# 2097         3.500         286
#
# [2098 rows x 7 columns]

# %%
df.to_csv('tvshows.csv')
